# %% [markdown]
# ## Lead Scoring Case Study

# %%
#Importing libraries

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler

# %%
#Suppressing unnecessary warnings
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Importing Data

# %%
leads = pd.read_csv("Leads.csv")
leads.head()
# Out:
#                             Prospect ID  Lead Number              Lead Origin  \
# 0  7927b2df-8bba-4d29-b9a2-b6e0beafe620       660737                      API
# 1  2a272436-5132-4136-86fa-dcc88c88f482       660728                      API
# 2  8cc8c611-a219-4f35-ad23-fdfd2656bd8a       660727  Landing Page Submission
# 3  0cc2df48-7cf4-4e39-9de9-19797f9b38cc       660719  Landing Page Submission
# 4  3256f628-e534-4826-9d63-4a8b88782852       660681  Landing Page Submission
#
#       Lead Source Do Not Email Do Not Call  Converted  TotalVisits  \
# 0      Olark Chat           No          No          0          0.0
# 1  Organic Search           No          No          0          5.0
# 2  Direct Traffic           No          No          1          2.0
# 3  Direct Traffic           No          No          0          1.0
# 4          Google           No          No          1          2.0
#
#    Total Time Spent on Website  Page Views Per Visit  ...  \
# ...

# %% [markdown]
# ## Analyse basic shape

# %%
leads.shape
# Out:
# (9240, 37)

# %%
leads.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9240 entries, 0 to 9239
# Data columns (total 37 columns):
#  #   Column                                         Non-Null Count  Dtype
# ---  ------                                         --------------  -----
#  0   Prospect ID                                    9240 non-null   object
#  1   Lead Number                                    9240 non-null   int64
#  2   Lead Origin                                    9240 non-null   object
#  3   Lead Source                                    9204 non-null   object
#  4   Do Not Email                                   9240 non-null   object
#  5   Do Not Call                                    9240 non-null   object
#  6   Converted                                      9240 non-null   int64
#  7   TotalVisits                                    9103 non-null   float64
#  8   Total Time Spent on Website                    9240 non-null   int64
# ...

# %% [markdown]
# ## Check for null values and remove columns greater then 40% null values

# %%
percent_missing = round(leads.isnull().sum() * 100 / len(leads),2)
percent_missing
# Out:
# Prospect ID                                       0.00
# Lead Number                                       0.00
# Lead Origin                                       0.00
# Lead Source                                       0.39
# Do Not Email                                      0.00
# Do Not Call                                       0.00
# Converted                                         0.00
# TotalVisits                                       1.48
# Total Time Spent on Website                       0.00
# Page Views Per Visit                              1.48
# Last Activity                                     1.11
# Country                                          26.63
# Specialization                                   15.56
# How did you hear about X Education               23.89
# What is your current occupation                  29.11
# What matters most to you in choosing a course    29.32
# Search                                            0.00
# ...

# %%
leads.drop(['Asymmetrique Activity Index','Asymmetrique Activity Score','Asymmetrique Profile Score'],axis=1,inplace=True)
leads.head()
# Out:
#                             Prospect ID  Lead Number              Lead Origin  \
# 0  7927b2df-8bba-4d29-b9a2-b6e0beafe620       660737                      API
# 1  2a272436-5132-4136-86fa-dcc88c88f482       660728                      API
# 2  8cc8c611-a219-4f35-ad23-fdfd2656bd8a       660727  Landing Page Submission
# 3  0cc2df48-7cf4-4e39-9de9-19797f9b38cc       660719  Landing Page Submission
# 4  3256f628-e534-4826-9d63-4a8b88782852       660681  Landing Page Submission
#
#       Lead Source Do Not Email Do Not Call  Converted  TotalVisits  \
# 0      Olark Chat           No          No          0          0.0
# 1  Organic Search           No          No          0          5.0
# 2  Direct Traffic           No          No          1          2.0
# 3  Direct Traffic           No          No          0          1.0
# 4          Google           No          No          1          2.0
#
#    Total Time Spent on Website  Page Views Per Visit  ...  \
# ...

# %%
percent_missing = round(leads.isnull().sum() * 100 / len(leads),2)
percent_missing
# Out:
# Prospect ID                                       0.00
# Lead Number                                       0.00
# Lead Origin                                       0.00
# Lead Source                                       0.39
# Do Not Email                                      0.00
# Do Not Call                                       0.00
# Converted                                         0.00
# TotalVisits                                       1.48
# Total Time Spent on Website                       0.00
# Page Views Per Visit                              1.48
# Last Activity                                     1.11
# Country                                          26.63
# Specialization                                   15.56
# How did you hear about X Education               23.89
# What is your current occupation                  29.11
# What matters most to you in choosing a course    29.32
# Search                                            0.00
# ...

# %% [markdown]
# ## Check number of unique values for each column

# %%
leads.nunique().sort_values(ascending=True)
# Out:
# Newspaper Article                                   2
# Do Not Email                                        2
# Do Not Call                                         2
# Converted                                           2
# A free copy of Mastering The Interview              2
# Search                                              2
# Through Recommendations                             2
# Digital Advertisement                               2
# Newspaper                                           2
# X Education Forums                                  2
# Asymmetrique Profile Index                          4
# What matters most to you in choosing a course       4
# Lead Origin                                         5
# Lead Quality                                        6
# Lead Profile                                        7
# What is your current occupation                     7
# City                                                8
# ...

# %%
leads = leads.loc[:,leads.apply(pd.Series.nunique) != 1]
leads.head()
# Out:
#                             Prospect ID  Lead Number              Lead Origin  \
# 0  7927b2df-8bba-4d29-b9a2-b6e0beafe620       660737                      API
# 1  2a272436-5132-4136-86fa-dcc88c88f482       660728                      API
# 2  8cc8c611-a219-4f35-ad23-fdfd2656bd8a       660727  Landing Page Submission
# 3  0cc2df48-7cf4-4e39-9de9-19797f9b38cc       660719  Landing Page Submission
# 4  3256f628-e534-4826-9d63-4a8b88782852       660681  Landing Page Submission
#
#       Lead Source Do Not Email Do Not Call  Converted  TotalVisits  \
# 0      Olark Chat           No          No          0          0.0
# 1  Organic Search           No          No          0          5.0
# 2  Direct Traffic           No          No          1          2.0
# 3  Direct Traffic           No          No          0          1.0
# 4          Google           No          No          1          2.0
#
#    Total Time Spent on Website  Page Views Per Visit  ... Newspaper  \
# ...

# %%
leads.nunique().sort_values(ascending=False)
# Out:
# Prospect ID                                      9240
# Lead Number                                      9240
# Total Time Spent on Website                      1731
# Page Views Per Visit                              114
# TotalVisits                                        41
# Country                                            39
# Tags                                               27
# Lead Source                                        22
# Specialization                                     20
# Last Activity                                      18
# Last Notable Activity                              16
# How did you hear about X Education                 11
# City                                                8
# What is your current occupation                     7
# Lead Profile                                        7
# Lead Quality                                        6
# Lead Origin                                         5
# ...

# %% [markdown]
# ## Bucket or drop the following categorical variables - Last activity, Country, Specialization, How did you hear about X Exucation, what is your current occupation, tags, Lead source

# %%
leads["Country"].value_counts()
# Out:
# India                   6492
# NA                      2461
# United States             69
# United Arab Emirates      53
# Singapore                 24
# Saudi Arabia              21
# United Kingdom            15
# Australia                 13
# Qatar                     10
# Bahrain                    7
# Hong Kong                  7
# Oman                       6
# France                     6
# unknown                    5
# Kuwait                     4
# South Africa               4
# Canada                     4
# Nigeria                    4
# Germany                    4
# Sweden                     3
# Philippines                2
# Uganda                     2
# Italy                      2
# Bangladesh                 2
# Netherlands                2
# Asia/Pacific Region        2
# China                      2
# Belgium                    2
# Ghana                      2
# Kenya                      1
# Sri Lanka                  1
# Tanzania                   1
# ...

# %%
cols_to_drop=['Country']

# %%
leads['What matters most to you in choosing a course'].value_counts()
# Out:
# Better Career Prospects      6528
# NA                           2709
# Flexibility & Convenience       2
# Other                           1
# Name: What matters most to you in choosing a course, dtype: int64

# %%
cols_to_drop.append('What matters most to you in choosing a course')

# %%
#Fill rest of the na values
#leads=leads.apply(lambda x: x.fillna(0) if x.dtype.kind in 'biufc' else x.fillna('NA'))
